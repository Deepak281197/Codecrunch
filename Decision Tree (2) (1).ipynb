# %% [markdown]
# # Company Data

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score,classification_report
import seaborn as sns

# %%
# Import Dataset
data=pd.read_csv('Company_Data.csv')

# %%
data
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# ...

# %%
data
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# ...

# %%
# conver the data into numeric
from sklearn.preprocessing import LabelEncoder

# %%
lab_enc=LabelEncoder()

# %%
data['ShelveLoc']=lab_enc.fit_transform(data['ShelveLoc'])

# %%
data
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120          0   42
# 1    11.22        111      48           16         260     83          1   65
# 2    10.06        113      35           10         269     80          2   59
# 3     7.40        117     100            4         466     97          2   55
# 4     4.15        141      64            3         340    128          0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395  12.57        138     108           17         203    128          1   33
# 396   6.14        139      23            3          37    120          2   55
# 397   7.41        162      26           12         368    159          2   40
# 398   5.94        100      79            7         284     95          0   50
# 399   9.71        134      37            0          27    120          1   49
#
#      Education Urban   US
# ...

# %%
data.shape
# Out:
# (400, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    int32
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: float64(1), int32(1), int64(7), object(2)
# memory usage: 32.9+ KB

# %%
data.describe()
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price   ShelveLoc         Age   Education
# count  400.000000  400.000000  400.000000  400.000000
# mean   115.795000    1.307500   53.322500   13.900000
# std     23.676664    0.833475   16.200297    2.620528
# min     24.000000    0.000000   25.000000   10.000000
# 25%    100.000000    1.000000   39.750000   12.000000
# ...

# %%
data.isnull().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# dtype: int64

# %%
target=data['ShelveLoc']

# %%
target
# Out:
# 0      0
# 1      1
# 2      2
# 3      2
# 4      0
#       ..
# 395    1
# 396    2
# 397    2
# 398    0
# 399    1
# Name: ShelveLoc, Length: 400, dtype: int32

# %%
data=data.drop(['ShelveLoc','Age','Education','Urban','US'],axis=1)

# %%
features=data

# %%
features
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price
# 0     9.50        138      73           11         276    120
# 1    11.22        111      48           16         260     83
# 2    10.06        113      35           10         269     80
# 3     7.40        117     100            4         466     97
# 4     4.15        141      64            3         340    128
# ..     ...        ...     ...          ...         ...    ...
# 395  12.57        138     108           17         203    128
# 396   6.14        139      23            3          37    120
# 397   7.41        162      26           12         368    159
# 398   5.94        100      79            7         284     95
# 399   9.71        134      37            0          27    120
#
# [400 rows x 6 columns]

# %%
# Visualization
sns.pairplot(data=data)

# %%
# split the data using traintest_split
from sklearn.model_selection import train_test_split,GridSearchCV

# %%
x_train,x_test,y_train,y_test=train_test_split(features,target,train_size=0.7,random_state=100)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (280, 6)
# (120, 6)
# (280,)
# (120,)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dec_tree=DecisionTreeClassifier(criterion='gini',splitter='best',max_depth=2)

# %%
dec_tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
y_pred=dec_tree.predict(x_test)

# %%
y_pred
# Out:
# array([0, 2, 2, 2, 2, 2, 2, 2, 1, 1, 2, 2, 2, 0, 2, 2, 2, 2, 2, 0, 2, 2,
#        0, 2, 1, 2, 2, 2, 1, 2, 1, 0, 1, 2, 1, 0, 1, 2, 0, 2, 0, 0, 2, 2,
#        0, 0, 2, 0, 2, 0, 2, 2, 0, 1, 0, 0, 2, 1, 2, 2, 2, 2, 2, 0, 1, 2,
#        2, 2, 1, 0, 2, 0, 2, 1, 1, 0, 2, 0, 2, 2, 2, 1, 0, 2, 1, 0, 2, 2,
#        0, 0, 1, 1, 0, 2, 2, 2, 2, 2, 0, 2, 2, 1, 2, 2, 0, 2, 2, 2, 2, 2,
#        2, 2, 2, 0, 0, 2, 2, 2, 2, 2])

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.5583333333333333

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.43      0.43      0.43        30
#            1       0.58      0.46      0.51        24
#            2       0.61      0.65      0.63        66
#
#     accuracy                           0.56       120
#    macro avg       0.54      0.51      0.52       120
# weighted avg       0.56      0.56      0.56       120

# %%
from sklearn import tree

# %%
tree.plot_tree(dec_tree);

# %% [markdown]
# # Fraud Check

# %%
# Import dataset
df1=pd.read_csv('Fraud_check.csv')

# %%
df1
# Out:
#     Undergrad Marital.Status  Taxable.Income  City.Population  \
# 0          NO         Single           68833            50047
# 1         YES       Divorced           33700           134075
# 2          NO        Married           36925           160205
# 3         YES         Single           50190           193264
# 4          NO        Married           81002            27533
# ..        ...            ...             ...              ...
# 595       YES       Divorced           76340            39492
# 596       YES       Divorced           69967            55369
# 597        NO       Divorced           47334           154058
# 598       YES        Married           98592           180083
# 599        NO       Divorced           96519           158137
#
#      Work.Experience Urban
# 0                 10   YES
# 1                 18   YES
# 2                 30   YES
# 3                 15   YES
# 4                 28    NO
# ..               ...   ...
# ...

# %%
# Split the data into two types using lamda
df1['Taxable.Income'] = df1['Taxable.Income'].apply(lambda x: 'Risky' if x <= 30000 else 'Good')

# %%
df1
# Out:
#     Undergrad Marital.Status Taxable.Income  City.Population  Work.Experience  \
# 0          NO         Single           Good            50047               10
# 1         YES       Divorced           Good           134075               18
# 2          NO        Married           Good           160205               30
# 3         YES         Single           Good           193264               15
# 4          NO        Married           Good            27533               28
# ..        ...            ...            ...              ...              ...
# 595       YES       Divorced           Good            39492                7
# 596       YES       Divorced           Good            55369                2
# 597        NO       Divorced           Good           154058                0
# 598       YES        Married           Good           180083               17
# 599        NO       Divorced           Good           158137               16
#
#     Urban
# 0     YES
# ...

# %%
df1=pd.get_dummies(df1,columns=['Undergrad','Marital.Status','Urban'],drop_first=True)

# %%
df1
# Out:
#     Taxable.Income  City.Population  Work.Experience  Undergrad_YES  \
# 0             Good            50047               10              0
# 1             Good           134075               18              1
# 2             Good           160205               30              0
# 3             Good           193264               15              1
# 4             Good            27533               28              0
# ..             ...              ...              ...            ...
# 595           Good            39492                7              1
# 596           Good            55369                2              1
# 597           Good           154058                0              0
# 598           Good           180083               17              1
# 599           Good           158137               16              0
#
#      Marital.Status_Married  Marital.Status_Single  Urban_YES
# 0                         0                      1          1
# ...

# %%
df1.isnull().sum()
# Out:
# Taxable.Income            0
# City.Population           0
# Work.Experience           0
# Undergrad_YES             0
# Marital.Status_Married    0
# Marital.Status_Single     0
# Urban_YES                 0
# dtype: int64

# %%
df1.describe()
# Out:
#        City.Population  Work.Experience  Undergrad_YES  \
# count       600.000000       600.000000     600.000000
# mean     108747.368333        15.558333       0.520000
# std       49850.075134         8.842147       0.500017
# min       25779.000000         0.000000       0.000000
# 25%       66966.750000         8.000000       0.000000
# 50%      106493.500000        15.000000       1.000000
# 75%      150114.250000        24.000000       1.000000
# max      199778.000000        30.000000       1.000000
#
#        Marital.Status_Married  Marital.Status_Single   Urban_YES
# count              600.000000             600.000000  600.000000
# mean                 0.323333               0.361667    0.503333
# std                  0.468139               0.480884    0.500406
# min                  0.000000               0.000000    0.000000
# 25%                  0.000000               0.000000    0.000000
# 50%                  0.000000               0.000000    1.000000
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Taxable.Income          600 non-null    object
#  1   City.Population         600 non-null    int64
#  2   Work.Experience         600 non-null    int64
#  3   Undergrad_YES           600 non-null    uint8
#  4   Marital.Status_Married  600 non-null    uint8
#  5   Marital.Status_Single   600 non-null    uint8
#  6   Urban_YES               600 non-null    uint8
# dtypes: int64(2), object(1), uint8(4)
# memory usage: 16.5+ KB

# %%
df1
# Out:
#     Taxable.Income  City.Population  Work.Experience  Undergrad_YES  \
# 0             Good            50047               10              0
# 1             Good           134075               18              1
# 2             Good           160205               30              0
# 3             Good           193264               15              1
# 4             Good            27533               28              0
# ..             ...              ...              ...            ...
# 595           Good            39492                7              1
# 596           Good            55369                2              1
# 597           Good           154058                0              0
# 598           Good           180083               17              1
# 599           Good           158137               16              0
#
#      Marital.Status_Married  Marital.Status_Single  Urban_YES
# 0                         0                      1          1
# ...

# %%
# let's plot pair plot to visualise the attributes all at once
sns.pairplot(data=df1, hue = 'Taxable.Income')

# %%
target=df1['Taxable.Income']

# %%
target
# Out:
# 0      Good
# 1      Good
# 2      Good
# 3      Good
# 4      Good
#        ...
# 595    Good
# 596    Good
# 597    Good
# 598    Good
# 599    Good
# Name: Taxable.Income, Length: 600, dtype: object

# %%
features=df1.drop('Taxable.Income',axis=1)

# %%
features
# Out:
#      City.Population  Work.Experience  Undergrad_YES  Marital.Status_Married  \
# 0              50047               10              0                       0
# 1             134075               18              1                       0
# 2             160205               30              0                       1
# 3             193264               15              1                       0
# 4              27533               28              0                       1
# ..               ...              ...            ...                     ...
# 595            39492                7              1                       0
# 596            55369                2              1                       0
# 597           154058                0              0                       0
# 598           180083               17              1                       1
# 599           158137               16              0                       0
#
#      Marital.Status_Single  Urban_YES
# ...

# %%
# Split the data into traintest_split
x_train,x_test,y_train,y_test=train_test_split(features,target,train_size=0.7,random_state=50)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (420, 6)
# (180, 6)
# (420,)
# (180,)

# %%
# Use model to predict
dec_tree=DecisionTreeClassifier(criterion='gini',splitter='best',max_depth=8)

# %%
dec_tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=8)

# %%
y_pred=dec_tree.predict(x_test)

# %%
y_pred
# Out:
# array(['Good', 'Good', 'Good', 'Risky', 'Good', 'Good', 'Good', 'Good',
#        'Risky', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Risky', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Risky',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Risky', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Risky', 'Good', 'Good', 'Risky', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Risky', 'Good', 'Good', 'Good', 'Good', 'Risky',
#        'Good', 'Good', 'Risky', 'Risky', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Risky', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
# ...

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7055555555555556

# %%
# Plot the decision tree
tree.plot_tree(dec_tree);
