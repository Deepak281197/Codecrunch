# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
dict1={'name':['deepak','kalai','ragu'],'age':[25,45,65],'location':['chennai','vellore','gudiyatta']}

# %%
dict1
# Out:
# {'name': ['deepak', 'kalai', 'ragu'],
#  'age': [25, 45, 65],
#  'location': ['chennai', 'vellore', 'gudiyatta']}

# %%
df=pd.DataFrame(data=dict1,index=[1,2,3])

# %%
df
# Out:
#      name  age   location
# 1  deepak   25    chennai
# 2   kalai   45    vellore
# 3    ragu   65  gudiyatta

# %%
df
# Out:
#      name  age   location
# 1  deepak   25    chennai
# 2   kalai   45    vellore
# 3    ragu   65  gudiyatta

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 9

# %%
ad= pd.read_csv('CARS_1.csv')

# %%
ad
# Out:
#     name_of_car                    Model                             Type  \
# 0         Acura   NSX coupe 2dr manual S                           Sports
# 1         Acura  3.5 RL w/Navigation 4dr                            Sedan
# 2         Acura               3.5 RL 4dr                            Sedan
# 3         Acura                      MDX                              NaN
# 4         Acura                   TL 4dr                              NaN
# ..          ...                      ...                              ...
# 438         NaN                      NaN                              NaN
# 439         NaN                      NaN                              NaN
# 440         NaN                group by                1) data will split
# 441         NaN                      NaN  2) apply the function mean(mpg)
# 442         NaN                      NaN                       3) combine
#
#     Origin DriveTrain      MSRP   Invoice  EngineSize  Cylinders  Horsepower  \
# ...

# %%
ad.size
# Out:
# 7088

# %%
ad.shape
# Out:
# (443, 16)

# %%
ad.head(10)
# Out:
#   name_of_car                    Model    Type  Origin DriveTrain      MSRP  \
# 0       Acura   NSX coupe 2dr manual S  Sports    Asia       Rear  $89,765
# 1       Acura  3.5 RL w/Navigation 4dr   Sedan    Asia      Front  $46,100
# 2       Acura               3.5 RL 4dr   Sedan    Asia      Front  $43,755
# 3       Acura                      MDX     NaN    Asia        All  $36,945
# 4       Acura                   TL 4dr     NaN    Asia      Front  $33,195
# 5       Acura                  TSX 4dr     NaN    Asia      Front  $26,990
# 6       Acura           RSX Type S 2dr     NaN    Asia      Front  $23,820
# 7        Audi                 RS 6 4dr     NaN  Europe      Front  $84,600
# 8        Audi         A8 L Quattro 4dr     NaN  Europe        All  $69,190
# 9        Audi       A6 4.2 Quattro 4dr     NaN  Europe        All  $49,690
#
#     Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# ...

# %%
ad.tail(12)
# Out:
#     name_of_car      Model                             Type Origin DriveTrain  \
# 431         NaN        NaN                              NaN    NaN        NaN
# 432         NaN        NaN                              NaN    NaN        NaN
# 433         NaN        NaN                              NaN    NaN        NaN
# 434         NaN        NaN                              NaN    NaN        NaN
# 435         NaN        NaN                              NaN    NaN        NaN
# 436         NaN        NaN                              NaN    NaN        NaN
# 437         NaN        NaN                              NaN    NaN        NaN
# 438         NaN        NaN                              NaN    NaN        NaN
# 439         NaN        NaN                              NaN    NaN        NaN
# 440         NaN  group by                1) data will split    NaN        NaN
# 441         NaN        NaN  2) apply the function mean(mpg)    NaN        NaN
# ...

# %%
ad.columns
# Out:
# Index(['name_of_car', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP',
#        'Invoice', 'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City',
#        'MPG_Highway', 'Weight', 'Wheelbase', 'Length', 'Unnamed: 15'],
#       dtype='object')

# %%
ad['name_of_car']
# Out:
# 0      Acura
# 1      Acura
# 2      Acura
# 3      Acura
# 4      Acura
#        ...
# 438      NaN
# 439      NaN
# 440      NaN
# 441      NaN
# 442      NaN
# Name: name_of_car, Length: 443, dtype: object

# %%
ad[['name_of_car','Type']]
# Out:
#     name_of_car                             Type
# 0         Acura                           Sports
# 1         Acura                            Sedan
# 2         Acura                            Sedan
# 3         Acura                              NaN
# 4         Acura                              NaN
# ..          ...                              ...
# 438         NaN                              NaN
# 439         NaN                              NaN
# 440         NaN               1) data will split
# 441         NaN  2) apply the function mean(mpg)
# 442         NaN                       3) combine
#
# [443 rows x 2 columns]

# %%
ad.iloc[0:5,0:4]
# Out:
#   name_of_car                    Model    Type Origin
# 0       Acura   NSX coupe 2dr manual S  Sports   Asia
# 1       Acura  3.5 RL w/Navigation 4dr   Sedan   Asia
# 2       Acura               3.5 RL 4dr   Sedan   Asia
# 3       Acura                      MDX     NaN   Asia
# 4       Acura                   TL 4dr     NaN   Asia

# %%
ad['Weight'].value_counts()
# Out:
# 3285.0    4
# 3450.0    4
# 3175.0    4
# 2692.0    3
# 3803.0    3
#          ..
# 3028.0    1
# 2691.0    1
# 2702.0    1
# 3290.0    1
# 2767.0    1
# Name: Weight, Length: 348, dtype: int64

# %%
ad
# Out:
#     name_of_car                    Model                             Type  \
# 0         Acura   NSX coupe 2dr manual S                           Sports
# 1         Acura  3.5 RL w/Navigation 4dr                            Sedan
# 2         Acura               3.5 RL 4dr                            Sedan
# 3         Acura                      MDX                              NaN
# 4         Acura                   TL 4dr                              NaN
# ..          ...                      ...                              ...
# 438         NaN                      NaN                              NaN
# 439         NaN                      NaN                              NaN
# 440         NaN                group by                1) data will split
# 441         NaN                      NaN  2) apply the function mean(mpg)
# 442         NaN                      NaN                       3) combine
#
#     Origin DriveTrain      MSRP   Invoice  EngineSize  Cylinders  Horsepower  \
# ...

# %%
ad.columns
# Out:
# Index(['name_of_car', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP',
#        'Invoice', 'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City',
#        'MPG_Highway', 'Weight', 'Wheelbase', 'Length', 'Unnamed: 15'],
#       dtype='object')

# %%
import pandas as dd

# %%
dict1={'name':['deepak','kalai','ragu'],'age':['25','45','65']}

# %%
dict1
# Out:
# {'name': ['deepak', 'kalai', 'ragu'], 'age': ['25', '45', '65']}

# %%
a=dd.DataFrame(index=[1,2,3],data=dict1)

# %%
a
# Out:
#      name age
# 1  deepak  25
# 2   kalai  45
# 3    ragu  65

# %%
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 a(1,2)
#
# TypeError: 'DataFrame' object is not callable

# %%
a=pd.read_csv('plant growth.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 a=pd.read_csv('plant growth.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
import pandas as pd

# %%
A=pd.read_csv('Plant_growth.csv')

# %%
A
# Out:
#     weight treatment_type
# 0     4.17           ctrl
# 1     5.58           ctrl
# 2     5.18           ctrl
# 3     6.11           ctrl
# 4     4.50           ctrl
# 5     4.61           ctrl
# 6     5.17           ctrl
# 7     4.53           ctrl
# 8     5.33           ctrl
# 9     5.14           ctrl
# 10    4.81           trt1
# 11    4.17           trt1
# 12    4.41           trt1
# 13    3.59           trt1
# 14    5.87           trt1
# 15    3.83           trt1
# 16    6.03           trt1
# 17    4.89           trt1
# 18    4.32           trt1
# 19    4.69           trt1
# 20    6.31           trt2
# 21    5.12           trt2
# 22    5.54           trt2
# 23    5.50           trt2
# 24    5.37           trt2
# 25    5.29           trt2
# 26    4.92           trt2
# 27    6.15           trt2
# 28    5.80           trt2
# 29    5.26           trt2

# %%
before= [185,192,206,177,225,168,256,239,199,218]
After= [169,187,193,176,194,171,228,217,204,195]

# %%
diff=[]
for i in range(len(After)):
    diff.append(After[i]-before[i])
diff
# Out:
# [-16, -5, -13, -1, -31, 3, -28, -22, 5, -23]
